# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import torch
from sklearn.metrics import f1_score,classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/home/ubuntu/uzair/NLP/text_classification_on_custom_dataset/AirlineTweets.csv")

# %%
df.head()
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
df.columns
# Out:
# Index(['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence',
#        'negativereason', 'negativereason_confidence', 'airline',
#        'airline_sentiment_gold', 'name', 'negativereason_gold',
#        'retweet_count', 'text', 'tweet_coord', 'tweet_created',
#        'tweet_location', 'user_timezone'],
#       dtype='object')

# %%
df = df[["text","airline_sentiment"]]

# %%
df['airline_sentiment'].hist()
# Out:
# <Axes: >

# %%
target_map = {"neutral": 2, "positive": 1,"negative": 2}

# %%
df['target'] = df['airline_sentiment'].map(target_map)

# %%
df.head()
# Out:
#                                                 text airline_sentiment  target
# 0                @VirginAmerica What @dhepburn said.           neutral       2
# 1  @VirginAmerica plus you've added commercials t...          positive       1
# 2  @VirginAmerica I didn't today... Must mean I n...           neutral       2
# 3  @VirginAmerica it's really aggressive to blast...          negative       2
# 4  @VirginAmerica and it's a really big bad thing...          negative       2

# %%
df2 = df[["text","target"]]

# %%
df2.head()
# Out:
#                                                 text  target
# 0                @VirginAmerica What @dhepburn said.       2
# 1  @VirginAmerica plus you've added commercials t...       1
# 2  @VirginAmerica I didn't today... Must mean I n...       2
# 3  @VirginAmerica it's really aggressive to blast...       2
# 4  @VirginAmerica and it's a really big bad thing...       2

# %%
df2= df.rename(columns={"target":"label",'text':'sentence'})

# %%
df2.head()
# Out:
#                                             sentence airline_sentiment  label
# 0                @VirginAmerica What @dhepburn said.           neutral      2
# 1  @VirginAmerica plus you've added commercials t...          positive      1
# 2  @VirginAmerica I didn't today... Must mean I n...           neutral      2
# 3  @VirginAmerica it's really aggressive to blast...          negative      2
# 4  @VirginAmerica and it's a really big bad thing...          negative      2

# %%
df2=df2.drop(columns='airline_sentiment',axis=1)

# %%
df2.to_csv("data.csv",index=False)

# %%
from datasets import load_dataset

# %%
raw_dataset = load_dataset('csv',data_files='data.csv')
# Out:
# Downloading data files: 100%|██████████| 1/1 [00:00<00:00, 9709.04it/s]
# Extracting data files: 100%|██████████| 1/1 [00:00<00:00, 1364.89it/s]
# Generating train split: 14640 examples [00:00, 481778.61 examples/s]

# %%
raw_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 14640
#     })
# })

# %%
split = raw_dataset['train'].train_test_split(test_size=0.3,seed=42)

# %%
split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 10248
#     })
#     test: Dataset({
#         features: ['sentence', 'label'],
#         num_rows: 4392
#     })
# })

# %%
checkpoint = "distilbert-base-cased"

# %%
from transformers import AutoTokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
# Out:
# Downloading (…)okenizer_config.json: 100%|██████████| 29.0/29.0 [00:00<00:00, 4.58kB/s]
# Downloading (…)lve/main/config.json: 100%|██████████| 465/465 [00:00<00:00, 93.4kB/s]
# Downloading (…)solve/main/vocab.txt: 100%|██████████| 213k/213k [00:00<00:00, 554kB/s]
# Downloading (…)/main/tokenizer.json: 100%|██████████| 436k/436k [00:00<00:00, 757kB/s]

# %%
def tokenize_func(batch):
    return tokenizer(batch['sentence'],truncation=True)

# %%
tokenized_datasets = split.map(tokenize_func,batched=True)
# Out:
# Map: 100%|██████████| 10248/10248 [00:00<00:00, 21352.58 examples/s]
# Map: 100%|██████████| 4392/4392 [00:00<00:00, 32711.91 examples/s]

# %%
from transformers import AutoModelForSequenceClassification, Trainer, TrainingArguments

# %%
model = AutoModelForSequenceClassification.from_pretrained(checkpoint,num_labels =3)
# Out:
# Downloading model.safetensors: 100%|██████████| 263M/263M [00:01<00:00, 257MB/s]
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-cased and are newly initialized: ['pre_classifier.weight', 'pre_classifier.bias', 'classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torchinfo import summary

# %%
summary(model)
# Out:
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# DistilBertForSequenceClassification                     --
# ├─DistilBertModel: 1-1                                  --
# │    └─Embeddings: 2-1                                  --
# │    │    └─Embedding: 3-1                              22,268,928
# │    │    └─Embedding: 3-2                              393,216
# │    │    └─LayerNorm: 3-3                              1,536
# │    │    └─Dropout: 3-4                                --
# │    └─Transformer: 2-2                                 --
# │    │    └─ModuleList: 3-5                             42,527,232
# ├─Linear: 1-2                                           590,592
# ├─Linear: 1-3                                           2,307
# ├─Dropout: 1-4                                          --
# ================================================================================
# Total params: 65,783,811
# Trainable params: 65,783,811
# Non-trainable params: 0
# ================================================================================

# %%
training_args = TrainingArguments(
    output_dir = "training_dir",
    evaluation_strategy = 'epoch',
    save_strategy="epoch",
    num_train_epochs=3,
    per_device_eval_batch_size=16,
    per_gpu_eval_batch_size=64
)

# %%
def compute_metrics(logits_and_labels):
    logits, labels = logits_and_labels
    predictions = np.argmax(logits,axis=-1)
    accuracy = np.mean(predictions==labels)
    f1 = f1_score(labels,predictions,average='macro')
    return {"accuracy": accuracy, "f1 score":f1}

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets['train'],
    eval_dataset=tokenized_datasets['test'],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# You're using a DistilBertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='3843' max='3843' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3843/3843 01:59, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1 score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.259000</td>
#       <td>0.208779</td>
#       <td>0.923953</td>
#       <td>0.848453</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.179100</td>
#       <td>0.256195</td>
#       <td>0.933515</td>
#       <td>0.866308</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.099100</td>
#       <td>0.307706</td>
#       <td>0.933515</td>
#       <td>0.867339</td>
#     </tr>
#   </tbody>
# </table><p>
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# Using deprecated `--per_gpu_eval_batch_size` argument which will be removed in a future version. Using `--per_device_eval_batch_size` is preferred.
# TrainOutput(global_step=3843, training_loss=0.1901529988614712, metrics={'train_runtime': 122.0068, 'train_samples_per_second': 251.986, 'train_steps_per_second': 31.498, 'total_flos': 359638842460032.0, 'train_loss': 0.1901529988614712, 'epoch': 3.0})

# %%
from transformers import pipeline

# %%
savedmodel = pipeline('text-classification',
                      model='training_dir/checkpoint-3843',device=0)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
split['test']
# Out:
# Dataset({
#     features: ['sentence', 'label'],
#     num_rows: 4392
# })

# %%
test_preds = savedmodel(split['test']['sentence'])

# %%
test_preds
# Out:
# [{'label': 'LABEL_1', 'score': 0.9906533360481262},
#  {'label': 'LABEL_1', 'score': 0.9894772171974182},
#  {'label': 'LABEL_1', 'score': 0.9425595998764038},
#  {'label': 'LABEL_1', 'score': 0.9720770716667175},
#  {'label': 'LABEL_2', 'score': 0.9979698061943054},
#  {'label': 'LABEL_2', 'score': 0.9998262524604797},
#  {'label': 'LABEL_2', 'score': 0.999297022819519},
#  {'label': 'LABEL_2', 'score': 0.9994990825653076},
#  {'label': 'LABEL_1', 'score': 0.9857558608055115},
#  {'label': 'LABEL_2', 'score': 0.9998409748077393},
#  {'label': 'LABEL_2', 'score': 0.9998478889465332},
#  {'label': 'LABEL_2', 'score': 0.9998637437820435},
#  {'label': 'LABEL_1', 'score': 0.9810787439346313},
#  {'label': 'LABEL_2', 'score': 0.9998524188995361},
#  {'label': 'LABEL_2', 'score': 0.999043881893158},
#  {'label': 'LABEL_2', 'score': 0.9991518259048462},
#  {'label': 'LABEL_2', 'score': 0.9994309544563293},
#  {'label': 'LABEL_2', 'score': 0.9998016953468323},
#  {'label': 'LABEL_2', 'score': 0.9994008541107178},
#  {'label': 'LABEL_2', 'score': 0.9996938705444336},
#  {'label': 'LABEL_2', 'score': 0.9998317956924438},
#  {'label': 'LABEL_2', 'score': 0.9998787641525269},
#  {'label': 'LABEL_2', 'score': 0.9955702424049377},
#  {'label': 'LABEL_1', 'score': 0.9889580011367798},
#  {'label': 'LABEL_2', 'score': 0.9998192191123962},
#  {'label': 'LABEL_2', 'score': 0.9983102083206177},
#  {'label': 'LABEL_2', 'score': 0.9998680353164673},
#  {'label': 'LABEL_2', 'score': 0.9998636245727539},
#  {'label': 'LABEL_2', 'score': 0.9998801946640015},
#  {'label': 'LABEL_2', 'score': 0.9997861981391907},
#  {'label': 'LABEL_2', 'score': 0.9998782873153687},
#  {'label': 'LABEL_1', 'score': 0.9216962456703186},
#  {'label': 'LABEL_2', 'score': 0.9998782873153687},
#  {'label': 'LABEL_2', 'score': 0.9998350143432617},
#  {'label': 'LABEL_1', 'score': 0.9908068776130676},
#  {'label': 'LABEL_2', 'score': 0.9998643398284912},
#  {'label': 'LABEL_2', 'score': 0.5584665536880493},
#  {'label': 'LABEL_2', 'score': 0.9995742440223694},
#  {'label': 'LABEL_2', 'score': 0.9998111128807068},
#  {'label': 'LABEL_2', 'score': 0.9998056292533875},
#  {'label': 'LABEL_2', 'score': 0.9998716115951538},
#  {'label': 'LABEL_2', 'score': 0.999850869178772},
#  {'label': 'LABEL_2', 'score': 0.9984920024871826},
#  {'label': 'LABEL_2', 'score': 0.9995858073234558},
#  {'label': 'LABEL_1', 'score': 0.9876289367675781},
#  {'label': 'LABEL_2', 'score': 0.9983392953872681},
#  {'label': 'LABEL_2', 'score': 0.9998687505722046},
#  {'label': 'LABEL_1', 'score': 0.9862955212593079},
#  {'label': 'LABEL_2', 'score': 0.9998494386672974},
#  {'label': 'LABEL_2', 'score': 0.9998051524162292},
#  {'label': 'LABEL_2', 'score': 0.9998525381088257},
#  {'label': 'LABEL_2', 'score': 0.999270498752594},
#  {'label': 'LABEL_2', 'score': 0.9966530203819275},
#  {'label': 'LABEL_2', 'score': 0.9998464584350586},
#  {'label': 'LABEL_2', 'score': 0.9998099207878113},
#  {'label': 'LABEL_2', 'score': 0.999875545501709},
#  {'label': 'LABEL_2', 'score': 0.99970942735672},
#  {'label': 'LABEL_2', 'score': 0.999786913394928},
#  {'label': 'LABEL_2', 'score': 0.9998739957809448},
#  {'label': 'LABEL_1', 'score': 0.9825312495231628},
#  {'label': 'LABEL_2', 'score': 0.9997513890266418},
#  {'label': 'LABEL_2', 'score': 0.9998550415039062},
#  {'label': 'LABEL_2', 'score': 0.9998283386230469},
#  {'label': 'LABEL_2', 'score': 0.9998666048049927},
#  {'label': 'LABEL_2', 'score': 0.9998500347137451},
#  {'label': 'LABEL_2', 'score': 0.9989952445030212},
#  {'label': 'LABEL_2', 'score': 0.9998233914375305},
#  {'label': 'LABEL_2', 'score': 0.9997969269752502},
#  {'label': 'LABEL_2', 'score': 0.9998051524162292},
#  {'label': 'LABEL_2', 'score': 0.9980615973472595},
#  {'label': 'LABEL_2', 'score': 0.9998164772987366},
#  {'label': 'LABEL_2', 'score': 0.9998670816421509},
#  {'label': 'LABEL_2', 'score': 0.9995166063308716},
#  {'label': 'LABEL_2', 'score': 0.9998506307601929},
#  {'label': 'LABEL_2', 'score': 0.9994827508926392},
#  {'label': 'LABEL_2', 'score': 0.9997413754463196},
#  {'label': 'LABEL_2', 'score': 0.9998631477355957},
#  {'label': 'LABEL_2', 'score': 0.9998021721839905},
#  {'label': 'LABEL_2', 'score': 0.9997392296791077},
#  {'label': 'LABEL_2', 'score': 0.9996755123138428},
#  {'label': 'LABEL_2', 'score': 0.999882698059082},
#  {'label': 'LABEL_2', 'score': 0.9944728016853333},
#  {'label': 'LABEL_1', 'score': 0.9884476065635681},
#  {'label': 'LABEL_2', 'score': 0.9996609687805176},
#  {'label': 'LABEL_1', 'score': 0.9876008033752441},
#  {'label': 'LABEL_2', 'score': 0.9995631575584412},
#  {'label': 'LABEL_2', 'score': 0.9998359680175781},
#  {'label': 'LABEL_2', 'score': 0.9979251623153687},
#  {'label': 'LABEL_2', 'score': 0.9998791217803955},
#  {'label': 'LABEL_2', 'score': 0.9975881576538086},
#  {'label': 'LABEL_2', 'score': 0.9995880722999573},
#  {'label': 'LABEL_2', 'score': 0.9995251893997192},
#  {'label': 'LABEL_2', 'score': 0.9998753070831299},
#  {'label': 'LABEL_2', 'score': 0.9600580334663391},
#  {'label': 'LABEL_2', 'score': 0.9998736381530762},
#  {'label': 'LABEL_2', 'score': 0.9998779296875},
#  {'label': 'LABEL_2', 'score': 0.9998708963394165},
#  {'label': 'LABEL_2', 'score': 0.999882698059082},
#  {'label': 'LABEL_2', 'score': 0.9998433589935303},
#  {'label': 'LABEL_2', 'score': 0.9997662901878357},
#  {'label': 'LABEL_2', 'score': 0.9997687935829163},
#  {'label': 'LABEL_2', 'score': 0.9997203946113586},
#  {'label': 'LABEL_2', 'score': 0.9990412592887878},
#  {'label': 'LABEL_2', 'score': 0.9781947731971741},
#  {'label': 'LABEL_2', 'score': 0.9632579684257507},
#  {'label': 'LABEL_2', 'score': 0.9994415640830994},
#  {'label': 'LABEL_2', 'score': 0.9992260932922363},
#  {'label': 'LABEL_2', 'score': 0.9995359182357788},
#  {'label': 'LABEL_2', 'score': 0.9998633861541748},
#  {'label': 'LABEL_2', 'score': 0.9998385906219482},
#  {'label': 'LABEL_2', 'score': 0.9994000196456909},
#  {'label': 'LABEL_2', 'score': 0.9998669624328613},
#  {'label': 'LABEL_2', 'score': 0.9998643398284912},
#  {'label': 'LABEL_2', 'score': 0.9991679191589355},
#  {'label': 'LABEL_2', 'score': 0.9990027546882629},
#  {'label': 'LABEL_2', 'score': 0.9498037695884705},
#  {'label': 'LABEL_2', 'score': 0.9991655349731445},
#  {'label': 'LABEL_2', 'score': 0.9871464967727661},
#  {'label': 'LABEL_2', 'score': 0.9998540878295898},
#  {'label': 'LABEL_2', 'score': 0.9992893934249878},
#  {'label': 'LABEL_2', 'score': 0.9994553923606873},
#  {'label': 'LABEL_2', 'score': 0.9965846538543701},
#  {'label': 'LABEL_2', 'score': 0.9985570311546326},
#  {'label': 'LABEL_2', 'score': 0.9998019337654114},
#  {'label': 'LABEL_2', 'score': 0.9998356103897095},
#  {'label': 'LABEL_2', 'score': 0.9998695850372314},
#  {'label': 'LABEL_2', 'score': 0.9997780919075012},
#  {'label': 'LABEL_2', 'score': 0.9998694658279419},
#  {'label': 'LABEL_2', 'score': 0.9964215755462646},
#  {'label': 'LABEL_2', 'score': 0.9998606443405151},
#  {'label': 'LABEL_1', 'score': 0.9905169606208801},
#  {'label': 'LABEL_2', 'score': 0.9998486042022705},
#  {'label': 'LABEL_2', 'score': 0.9998472929000854},
#  {'label': 'LABEL_1', 'score': 0.990517795085907},
#  {'label': 'LABEL_2', 'score': 0.9952242374420166},
#  {'label': 'LABEL_2', 'score': 0.9995098114013672},
#  {'label': 'LABEL_2', 'score': 0.999808132648468},
#  {'label': 'LABEL_2', 'score': 0.9998354911804199},
#  {'label': 'LABEL_2', 'score': 0.9998747110366821},
#  {'label': 'LABEL_2', 'score': 0.999872088432312},
#  {'label': 'LABEL_2', 'score': 0.9995319843292236},
#  {'label': 'LABEL_2', 'score': 0.9968173503875732},
#  {'label': 'LABEL_2', 'score': 0.9998495578765869},
#  {'label': 'LABEL_2', 'score': 0.999326229095459},
#  {'label': 'LABEL_2', 'score': 0.998236894607544},
#  {'label': 'LABEL_2', 'score': 0.9998430013656616},
#  {'label': 'LABEL_2', 'score': 0.9998466968536377},
#  {'label': 'LABEL_2', 'score': 0.9998652935028076},
#  {'label': 'LABEL_2', 'score': 0.999800980091095},
#  {'label': 'LABEL_2', 'score': 0.9998542070388794},
#  {'label': 'LABEL_2', 'score': 0.9998431205749512},
#  {'label': 'LABEL_2', 'score': 0.9381206035614014},
#  {'label': 'LABEL_2', 'score': 0.9998553991317749},
#  {'label': 'LABEL_2', 'score': 0.9905133247375488},
#  {'label': 'LABEL_1', 'score': 0.9860166907310486},
#  {'label': 'LABEL_2', 'score': 0.8605008721351624},
#  {'label': 'LABEL_2', 'score': 0.9997636675834656},
#  {'label': 'LABEL_2', 'score': 0.9997920393943787},
#  {'label': 'LABEL_2', 'score': 0.9998599290847778},
#  {'label': 'LABEL_2', 'score': 0.9996356964111328},
#  {'label': 'LABEL_2', 'score': 0.999460756778717},
#  {'label': 'LABEL_2', 'score': 0.9997832179069519},
#  {'label': 'LABEL_2', 'score': 0.9910377264022827},
#  {'label': 'LABEL_2', 'score': 0.9996600151062012},
#  {'label': 'LABEL_2', 'score': 0.9993236064910889},
#  {'label': 'LABEL_2', 'score': 0.9997106194496155},
#  {'label': 'LABEL_2', 'score': 0.9998836517333984},
#  {'label': 'LABEL_2', 'score': 0.9998749494552612},
#  {'label': 'LABEL_2', 'score': 0.9998257756233215},
#  {'label': 'LABEL_2', 'score': 0.9994614720344543},
#  {'label': 'LABEL_2', 'score': 0.9988974332809448},
#  {'label': 'LABEL_2', 'score': 0.9995383024215698},
#  {'label': 'LABEL_2', 'score': 0.9966615438461304},
#  {'label': 'LABEL_2', 'score': 0.9991846680641174},
#  {'label': 'LABEL_2', 'score': 0.9572513699531555},
#  {'label': 'LABEL_1', 'score': 0.9871310591697693},
#  {'label': 'LABEL_2', 'score': 0.9998598098754883},
#  {'label': 'LABEL_2', 'score': 0.9998375177383423},
#  {'label': 'LABEL_2', 'score': 0.9996873140335083},
#  {'label': 'LABEL_2', 'score': 0.9998573064804077},
#  {'label': 'LABEL_2', 'score': 0.9998014569282532},
#  {'label': 'LABEL_2', 'score': 0.9739580154418945},
#  {'label': 'LABEL_2', 'score': 0.9998681545257568},
#  {'label': 'LABEL_2', 'score': 0.9997226595878601},
#  {'label': 'LABEL_2', 'score': 0.999829888343811},
#  {'label': 'LABEL_2', 'score': 0.9981850981712341},
#  {'label': 'LABEL_2', 'score': 0.9994719624519348},
#  {'label': 'LABEL_2', 'score': 0.9997512698173523},
#  {'label': 'LABEL_1', 'score': 0.9899685978889465},
#  {'label': 'LABEL_2', 'score': 0.9998190999031067},
#  {'label': 'LABEL_2', 'score': 0.999713122844696},
#  {'label': 'LABEL_2', 'score': 0.9998716115951538},
#  {'label': 'LABEL_2', 'score': 0.9996967315673828},
#  {'label': 'LABEL_2', 'score': 0.9982280135154724},
#  {'label': 'LABEL_2', 'score': 0.9954498410224915},
#  {'label': 'LABEL_2', 'score': 0.9991672039031982},
#  {'label': 'LABEL_1', 'score': 0.990190863609314},
#  {'label': 'LABEL_2', 'score': 0.9998711347579956},
#  {'label': 'LABEL_2', 'score': 0.9998315572738647},
#  {'label': 'LABEL_2', 'score': 0.9997407793998718},
#  {'label': 'LABEL_2', 'score': 0.9997873902320862},
#  {'label': 'LABEL_2', 'score': 0.9998373985290527},
#  {'label': 'LABEL_2', 'score': 0.9992538094520569},
#  {'label': 'LABEL_2', 'score': 0.9998323917388916},
#  {'label': 'LABEL_2', 'score': 0.999836802482605},
#  {'label': 'LABEL_1', 'score': 0.959858775138855},
#  {'label': 'LABEL_2', 'score': 0.999599039554596},
#  {'label': 'LABEL_2', 'score': 0.9998664855957031},
#  {'label': 'LABEL_2', 'score': 0.9997954964637756},
#  {'label': 'LABEL_2', 'score': 0.9982597231864929},
#  {'label': 'LABEL_2', 'score': 0.9997162222862244},
#  {'label': 'LABEL_2', 'score': 0.9993590712547302},
#  {'label': 'LABEL_1', 'score': 0.9880669116973877},
#  {'label': 'LABEL_2', 'score': 0.9997498393058777},
#  {'label': 'LABEL_2', 'score': 0.9977783560752869},
#  {'label': 'LABEL_2', 'score': 0.9996603727340698},
#  {'label': 'LABEL_2', 'score': 0.9996284246444702},
#  {'label': 'LABEL_2', 'score': 0.9998774528503418},
#  {'label': 'LABEL_2', 'score': 0.9998466968536377},
#  {'label': 'LABEL_2', 'score': 0.9526563882827759},
#  {'label': 'LABEL_2', 'score': 0.9993822574615479},
#  {'label': 'LABEL_2', 'score': 0.9998571872711182},
#  {'label': 'LABEL_2', 'score': 0.9992212057113647},
#  {'label': 'LABEL_2', 'score': 0.9968820810317993},
#  {'label': 'LABEL_1', 'score': 0.9877569675445557},
#  {'label': 'LABEL_2', 'score': 0.9998620748519897},
#  {'label': 'LABEL_2', 'score': 0.9937644004821777},
#  {'label': 'LABEL_2', 'score': 0.9998592138290405},
#  {'label': 'LABEL_2', 'score': 0.9998579025268555},
#  {'label': 'LABEL_2', 'score': 0.9998041987419128},
#  {'label': 'LABEL_2', 'score': 0.9995513558387756},
#  {'label': 'LABEL_2', 'score': 0.9998477697372437},
#  {'label': 'LABEL_2', 'score': 0.999054491519928},
#  {'label': 'LABEL_2', 'score': 0.9998605251312256},
#  {'label': 'LABEL_2', 'score': 0.9998756647109985},
#  {'label': 'LABEL_1', 'score': 0.9869478940963745},
#  {'label': 'LABEL_2', 'score': 0.9994423985481262},
#  {'label': 'LABEL_2', 'score': 0.9998500347137451},
#  {'label': 'LABEL_2', 'score': 0.9998641014099121},
#  {'label': 'LABEL_2', 'score': 0.9940879344940186},
#  {'label': 'LABEL_2', 'score': 0.9970268607139587},
#  {'label': 'LABEL_2', 'score': 0.9997962117195129},
#  {'label': 'LABEL_2', 'score': 0.9572950601577759},
#  {'label': 'LABEL_2', 'score': 0.9984248876571655},
#  {'label': 'LABEL_2', 'score': 0.9998624324798584},
#  {'label': 'LABEL_2', 'score': 0.9995787739753723},
#  {'label': 'LABEL_2', 'score': 0.9998457431793213},
#  {'label': 'LABEL_2', 'score': 0.9994633793830872},
#  {'label': 'LABEL_2', 'score': 0.9997804760932922},
#  {'label': 'LABEL_2', 'score': 0.9987951517105103},
#  {'label': 'LABEL_2', 'score': 0.9998095631599426},
#  {'label': 'LABEL_2', 'score': 0.9998546838760376},
#  {'label': 'LABEL_2', 'score': 0.9998672008514404},
#  {'label': 'LABEL_2', 'score': 0.9997476935386658},
#  {'label': 'LABEL_2', 'score': 0.9998607635498047},
#  {'label': 'LABEL_2', 'score': 0.9998154044151306},
#  {'label': 'LABEL_2', 'score': 0.9996451139450073},
#  {'label': 'LABEL_2', 'score': 0.9998538494110107},
#  {'label': 'LABEL_2', 'score': 0.9952771663665771},
#  {'label': 'LABEL_2', 'score': 0.9990667700767517},
#  {'label': 'LABEL_1', 'score': 0.9892711639404297},
#  {'label': 'LABEL_2', 'score': 0.9998396635055542},
#  {'label': 'LABEL_2', 'score': 0.9990946054458618},
#  {'label': 'LABEL_1', 'score': 0.9909690022468567},
#  {'label': 'LABEL_1', 'score': 0.9860253930091858},
#  {'label': 'LABEL_2', 'score': 0.9955803751945496},
#  {'label': 'LABEL_2', 'score': 0.9997485280036926},
#  {'label': 'LABEL_2', 'score': 0.999739944934845},
#  {'label': 'LABEL_2', 'score': 0.9960116147994995},
#  {'label': 'LABEL_1', 'score': 0.9899073839187622},
#  {'label': 'LABEL_2', 'score': 0.9998180270195007},
#  {'label': 'LABEL_2', 'score': 0.9998223185539246},
#  {'label': 'LABEL_2', 'score': 0.9930140376091003},
#  {'label': 'LABEL_2', 'score': 0.9998338222503662},
#  {'label': 'LABEL_2', 'score': 0.9994865655899048},
#  {'label': 'LABEL_2', 'score': 0.9981757402420044},
#  {'label': 'LABEL_2', 'score': 0.9998687505722046},
#  {'label': 'LABEL_2', 'score': 0.8711123466491699},
#  {'label': 'LABEL_2', 'score': 0.9994924068450928},
#  {'label': 'LABEL_2', 'score': 0.9998592138290405},
#  {'label': 'LABEL_2', 'score': 0.9998551607131958},
#  {'label': 'LABEL_2', 'score': 0.9998420476913452},
#  {'label': 'LABEL_2', 'score': 0.9889074563980103},
#  {'label': 'LABEL_2', 'score': 0.999836802482605},
#  {'label': 'LABEL_1', 'score': 0.9899829626083374},
#  {'label': 'LABEL_2', 'score': 0.999792754650116},
#  {'label': 'LABEL_2', 'score': 0.999835729598999},
#  {'label': 'LABEL_2', 'score': 0.9998283386230469},
#  {'label': 'LABEL_2', 'score': 0.9998763799667358},
#  {'label': 'LABEL_2', 'score': 0.9998713731765747},
#  {'label': 'LABEL_2', 'score': 0.9998437166213989},
#  {'label': 'LABEL_2', 'score': 0.9998605251312256},
#  {'label': 'LABEL_2', 'score': 0.9606046676635742},
#  {'label': 'LABEL_2', 'score': 0.993669331073761},
#  {'label': 'LABEL_2', 'score': 0.999858021736145},
#  {'label': 'LABEL_2', 'score': 0.9994612336158752},
#  {'label': 'LABEL_2', 'score': 0.9998369216918945},
#  {'label': 'LABEL_2', 'score': 0.9995397329330444},
#  {'label': 'LABEL_2', 'score': 0.9996583461761475},
#  {'label': 'LABEL_2', 'score': 0.9996371269226074},
#  {'label': 'LABEL_2', 'score': 0.9997782111167908},
#  {'label': 'LABEL_2', 'score': 0.9997166991233826},
#  {'label': 'LABEL_2', 'score': 0.9323520064353943},
#  {'label': 'LABEL_2', 'score': 0.9997264742851257},
#  {'label': 'LABEL_2', 'score': 0.9957297444343567},
#  {'label': 'LABEL_2', 'score': 0.9996007084846497},
#  {'label': 'LABEL_1', 'score': 0.9766612648963928},
#  {'label': 'LABEL_2', 'score': 0.9997703433036804},
#  {'label': 'LABEL_2', 'score': 0.9996236562728882},
#  {'label': 'LABEL_2', 'score': 0.9998551607131958},
#  {'label': 'LABEL_2', 'score': 0.9997091889381409},
#  {'label': 'LABEL_2', 'score': 0.9998661279678345},
#  {'label': 'LABEL_2', 'score': 0.9998527765274048},
#  {'label': 'LABEL_2', 'score': 0.9992805123329163},
#  {'label': 'LABEL_2', 'score': 0.9998569488525391},
#  {'label': 'LABEL_1', 'score': 0.9835153818130493},
#  {'label': 'LABEL_2', 'score': 0.9998359680175781},
#  {'label': 'LABEL_2', 'score': 0.9998781681060791},
#  {'label': 'LABEL_2', 'score': 0.9997650980949402},
#  {'label': 'LABEL_2', 'score': 0.999863862991333},
#  {'label': 'LABEL_2', 'score': 0.9998779296875},
#  {'label': 'LABEL_2', 'score': 0.9998082518577576},
#  {'label': 'LABEL_2', 'score': 0.9990412592887878},
#  {'label': 'LABEL_2', 'score': 0.9987295269966125},
#  {'label': 'LABEL_2', 'score': 0.9998500347137451},
#  {'label': 'LABEL_2', 'score': 0.9998599290847778},
#  {'label': 'LABEL_1', 'score': 0.9874610304832458},
#  {'label': 'LABEL_2', 'score': 0.9998526573181152},
#  {'label': 'LABEL_2', 'score': 0.9996645450592041},
#  {'label': 'LABEL_2', 'score': 0.9998155236244202},
#  {'label': 'LABEL_2', 'score': 0.9997476935386658},
#  {'label': 'LABEL_2', 'score': 0.9998795986175537},
#  {'label': 'LABEL_2', 'score': 0.9990054965019226},
#  {'label': 'LABEL_1', 'score': 0.980889618396759},
#  {'label': 'LABEL_2', 'score': 0.9998570680618286},
#  {'label': 'LABEL_2', 'score': 0.9997199177742004},
#  {'label': 'LABEL_2', 'score': 0.9997254014015198},
#  {'label': 'LABEL_2', 'score': 0.9991359114646912},
#  {'label': 'LABEL_2', 'score': 0.9991593360900879},
#  {'label': 'LABEL_1', 'score': 0.9889145493507385},
#  {'label': 'LABEL_2', 'score': 0.9998699426651001},
#  {'label': 'LABEL_2', 'score': 0.9997878670692444},
#  {'label': 'LABEL_2', 'score': 0.9998593330383301},
#  {'label': 'LABEL_2', 'score': 0.9998694658279419},
#  {'label': 'LABEL_2', 'score': 0.9997697472572327},
#  {'label': 'LABEL_2', 'score': 0.9998281002044678},
#  {'label': 'LABEL_2', 'score': 0.9995238780975342},
#  {'label': 'LABEL_2', 'score': 0.9995146989822388},
#  {'label': 'LABEL_2', 'score': 0.996792733669281},
#  {'label': 'LABEL_1', 'score': 0.9899871945381165},
#  {'label': 'LABEL_2', 'score': 0.9995167255401611},
#  {'label': 'LABEL_1', 'score': 0.9874372482299805},
#  {'label': 'LABEL_1', 'score': 0.9857683777809143},
#  {'label': 'LABEL_2', 'score': 0.9998743534088135},
#  {'label': 'LABEL_2', 'score': 0.9995669722557068},
#  {'label': 'LABEL_2', 'score': 0.9906187653541565},
#  {'label': 'LABEL_2', 'score': 0.999864935874939},
#  {'label': 'LABEL_1', 'score': 0.9859144687652588},
#  {'label': 'LABEL_2', 'score': 0.752716600894928},
#  {'label': 'LABEL_2', 'score': 0.9997959733009338},
#  {'label': 'LABEL_2', 'score': 0.9998773336410522},
#  {'label': 'LABEL_2', 'score': 0.9997716546058655},
#  {'label': 'LABEL_2', 'score': 0.9997195601463318},
#  {'label': 'LABEL_2', 'score': 0.9953976273536682},
#  {'label': 'LABEL_1', 'score': 0.5470248460769653},
#  {'label': 'LABEL_2', 'score': 0.9998164772987366},
#  {'label': 'LABEL_2', 'score': 0.9998568296432495},
#  {'label': 'LABEL_1', 'score': 0.9902599453926086},
#  {'label': 'LABEL_2', 'score': 0.9997314810752869},
#  {'label': 'LABEL_2', 'score': 0.9998241066932678},
#  {'label': 'LABEL_2', 'score': 0.9984158277511597},
#  {'label': 'LABEL_2', 'score': 0.9998169541358948},
#  {'label': 'LABEL_1', 'score': 0.9842797517776489},
#  {'label': 'LABEL_2', 'score': 0.9998501539230347},
#  {'label': 'LABEL_1', 'score': 0.9868161082267761},
#  {'label': 'LABEL_2', 'score': 0.9998643398284912},
#  {'label': 'LABEL_2', 'score': 0.9997170567512512},
#  {'label': 'LABEL_2', 'score': 0.9998608827590942},
#  {'label': 'LABEL_1', 'score': 0.9900736808776855},
#  {'label': 'LABEL_2', 'score': 0.9996604919433594},
#  {'label': 'LABEL_2', 'score': 0.9998582601547241},
#  {'label': 'LABEL_2', 'score': 0.9994192123413086},
#  {'label': 'LABEL_2', 'score': 0.9618679285049438},
#  {'label': 'LABEL_2', 'score': 0.999705970287323},
#  {'label': 'LABEL_1', 'score': 0.9908464550971985},
#  {'label': 'LABEL_2', 'score': 0.9996957778930664},
#  {'label': 'LABEL_2', 'score': 0.9998747110366821},
#  {'label': 'LABEL_1', 'score': 0.9904126524925232},
#  {'label': 'LABEL_1', 'score': 0.9895533323287964},
#  {'label': 'LABEL_2', 'score': 0.9984873533248901},
#  {'label': 'LABEL_2', 'score': 0.9998645782470703},
#  {'label': 'LABEL_2', 'score': 0.9998218417167664},
#  {'label': 'LABEL_2', 'score': 0.9998787641525269},
#  {'label': 'LABEL_2', 'score': 0.9998480081558228},
#  {'label': 'LABEL_1', 'score': 0.9890005588531494},
#  {'label': 'LABEL_2', 'score': 0.9998360872268677},
#  {'label': 'LABEL_2', 'score': 0.9998619556427002},
#  {'label': 'LABEL_1', 'score': 0.9858850240707397},
#  {'label': 'LABEL_2', 'score': 0.9998164772987366},
#  {'label': 'LABEL_2', 'score': 0.9994945526123047},
#  {'label': 'LABEL_1', 'score': 0.9840351343154907},
#  {'label': 'LABEL_1', 'score': 0.9847261309623718},
#  {'label': 'LABEL_2', 'score': 0.9991150498390198},
#  {'label': 'LABEL_2', 'score': 0.9998749494552612},
#  {'label': 'LABEL_2', 'score': 0.999869704246521},
#  {'label': 'LABEL_2', 'score': 0.9998596906661987},
#  {'label': 'LABEL_1', 'score': 0.9856793284416199},
#  {'label': 'LABEL_2', 'score': 0.9998722076416016},
#  {'label': 'LABEL_2', 'score': 0.9993064403533936},
#  {'label': 'LABEL_2', 'score': 0.9998263716697693},
#  {'label': 'LABEL_2', 'score': 0.9998786449432373},
#  {'label': 'LABEL_2', 'score': 0.9895055890083313},
#  {'label': 'LABEL_2', 'score': 0.9994995594024658},
#  {'label': 'LABEL_2', 'score': 0.9997159838676453},
#  {'label': 'LABEL_2', 'score': 0.9998353719711304},
#  {'label': 'LABEL_2', 'score': 0.9971283078193665},
#  {'label': 'LABEL_2', 'score': 0.9895318746566772},
#  {'label': 'LABEL_2', 'score': 0.9832479953765869},
#  {'label': 'LABEL_2', 'score': 0.9996398687362671},
#  {'label': 'LABEL_2', 'score': 0.9997195601463318},
#  {'label': 'LABEL_2', 'score': 0.9993327260017395},
#  {'label': 'LABEL_2', 'score': 0.9997239708900452},
#  {'label': 'LABEL_2', 'score': 0.9997383952140808},
#  {'label': 'LABEL_1', 'score': 0.9906777143478394},
#  {'label': 'LABEL_2', 'score': 0.9998536109924316},
#  {'label': 'LABEL_2', 'score': 0.999874472618103},
#  {'label': 'LABEL_2', 'score': 0.9989835619926453},
#  {'label': 'LABEL_2', 'score': 0.9996870756149292},
#  {'label': 'LABEL_2', 'score': 0.9998480081558228},
#  {'label': 'LABEL_2', 'score': 0.9998587369918823},
#  {'label': 'LABEL_2', 'score': 0.9993745684623718},
#  {'label': 'LABEL_2', 'score': 0.9997648596763611},
#  {'label': 'LABEL_1', 'score': 0.9832348823547363},
#  {'label': 'LABEL_2', 'score': 0.9991810917854309},
#  {'label': 'LABEL_2', 'score': 0.9997656941413879},
#  {'label': 'LABEL_2', 'score': 0.9997642636299133},
#  {'label': 'LABEL_2', 'score': 0.999680757522583},
#  {'label': 'LABEL_2', 'score': 0.9998704195022583},
#  {'label': 'LABEL_2', 'score': 0.9955370426177979},
#  {'label': 'LABEL_2', 'score': 0.9998704195022583},
#  {'label': 'LABEL_2', 'score': 0.999862790107727},
#  {'label': 'LABEL_1', 'score': 0.9854825735092163},
#  {'label': 'LABEL_2', 'score': 0.9930773973464966},
#  {'label': 'LABEL_2', 'score': 0.9949899315834045},
#  {'label': 'LABEL_2', 'score': 0.9998754262924194},
#  {'label': 'LABEL_1', 'score': 0.9770190119743347},
#  {'label': 'LABEL_2', 'score': 0.9996563196182251},
#  {'label': 'LABEL_2', 'score': 0.9998155236244202},
#  {'label': 'LABEL_2', 'score': 0.9997784495353699},
#  {'label': 'LABEL_2', 'score': 0.9998348951339722},
#  {'label': 'LABEL_2', 'score': 0.9998237490653992},
#  {'label': 'LABEL_2', 'score': 0.9075076580047607},
#  {'label': 'LABEL_2', 'score': 0.9989809393882751},
#  {'label': 'LABEL_2', 'score': 0.9995747208595276},
#  {'label': 'LABEL_2', 'score': 0.9998660087585449},
#  {'label': 'LABEL_2', 'score': 0.994586706161499},
#  {'label': 'LABEL_2', 'score': 0.999876856803894},
#  {'label': 'LABEL_1', 'score': 0.9890270233154297},
#  {'label': 'LABEL_2', 'score': 0.9963390827178955},
#  {'label': 'LABEL_2', 'score': 0.9998123049736023},
#  {'label': 'LABEL_2', 'score': 0.9998388290405273},
#  {'label': 'LABEL_2', 'score': 0.9996775388717651},
#  {'label': 'LABEL_2', 'score': 0.9991874098777771},
#  {'label': 'LABEL_2', 'score': 0.9998546838760376},
#  {'label': 'LABEL_2', 'score': 0.999763548374176},
#  {'label': 'LABEL_2', 'score': 0.9961026906967163},
#  {'label': 'LABEL_1', 'score': 0.9497605562210083},
#  {'label': 'LABEL_2', 'score': 0.9998569488525391},
#  {'label': 'LABEL_1', 'score': 0.9907917976379395},
#  {'label': 'LABEL_2', 'score': 0.9994432330131531},
#  {'label': 'LABEL_2', 'score': 0.9981631636619568},
#  {'label': 'LABEL_2', 'score': 0.999677300453186},
#  {'label': 'LABEL_2', 'score': 0.9998519420623779},
#  {'label': 'LABEL_2', 'score': 0.9996423721313477},
#  {'label': 'LABEL_2', 'score': 0.9987450838088989},
#  {'label': 'LABEL_2', 'score': 0.9996139407157898},
#  {'label': 'LABEL_2', 'score': 0.9997356534004211},
#  {'label': 'LABEL_2', 'score': 0.999828577041626},
#  {'label': 'LABEL_1', 'score': 0.9903292655944824},
#  {'label': 'LABEL_2', 'score': 0.9971470236778259},
#  {'label': 'LABEL_2', 'score': 0.9998599290847778},
#  {'label': 'LABEL_2', 'score': 0.9998613595962524},
#  {'label': 'LABEL_2', 'score': 0.9998527765274048},
#  {'label': 'LABEL_2', 'score': 0.9986822009086609},
#  {'label': 'LABEL_2', 'score': 0.9998775720596313},
#  {'label': 'LABEL_2', 'score': 0.9981654286384583},
#  {'label': 'LABEL_1', 'score': 0.976141095161438},
#  {'label': 'LABEL_2', 'score': 0.9995409250259399},
#  {'label': 'LABEL_2', 'score': 0.9994649291038513},
#  {'label': 'LABEL_2', 'score': 0.9998513460159302},
#  {'label': 'LABEL_2', 'score': 0.9995144605636597},
#  {'label': 'LABEL_2', 'score': 0.999761164188385},
#  {'label': 'LABEL_2', 'score': 0.9994611144065857},
#  {'label': 'LABEL_2', 'score': 0.9998652935028076},
#  {'label': 'LABEL_2', 'score': 0.9998699426651001},
#  {'label': 'LABEL_2', 'score': 0.9996322393417358},
#  {'label': 'LABEL_2', 'score': 0.9580150842666626},
#  {'label': 'LABEL_2', 'score': 0.9998456239700317},
#  {'label': 'LABEL_2', 'score': 0.9998568296432495},
#  {'label': 'LABEL_2', 'score': 0.9630873203277588},
#  {'label': 'LABEL_1', 'score': 0.9812396764755249},
#  {'label': 'LABEL_2', 'score': 0.9998152852058411},
#  {'label': 'LABEL_2', 'score': 0.9998589754104614},
#  {'label': 'LABEL_2', 'score': 0.9997794032096863},
#  {'label': 'LABEL_2', 'score': 0.9998626708984375},
#  {'label': 'LABEL_1', 'score': 0.9886034727096558},
#  {'label': 'LABEL_2', 'score': 0.9957744479179382},
#  {'label': 'LABEL_2', 'score': 0.9960536956787109},
#  {'label': 'LABEL_2', 'score': 0.9998471736907959},
#  {'label': 'LABEL_2', 'score': 0.9997567534446716},
#  {'label': 'LABEL_2', 'score': 0.9998646974563599},
#  {'label': 'LABEL_2', 'score': 0.9998637437820435},
#  {'label': 'LABEL_2', 'score': 0.9998536109924316},
#  {'label': 'LABEL_2', 'score': 0.999764621257782},
#  {'label': 'LABEL_2', 'score': 0.9998335838317871},
#  {'label': 'LABEL_2', 'score': 0.996235191822052},
#  {'label': 'LABEL_2', 'score': 0.9996517896652222},
#  {'label': 'LABEL_2', 'score': 0.9998703002929688},
#  {'label': 'LABEL_2', 'score': 0.999821126461029},
#  {'label': 'LABEL_2', 'score': 0.9998699426651001},
#  {'label': 'LABEL_2', 'score': 0.99986732006073},
#  {'label': 'LABEL_2', 'score': 0.9998589754104614},
#  {'label': 'LABEL_2', 'score': 0.999783456325531},
#  {'label': 'LABEL_2', 'score': 0.9996929168701172},
#  {'label': 'LABEL_2', 'score': 0.9987665414810181},
#  {'label': 'LABEL_2', 'score': 0.9998613595962524},
#  {'label': 'LABEL_2', 'score': 0.9996447563171387},
#  {'label': 'LABEL_1', 'score': 0.9897648096084595},
#  {'label': 'LABEL_2', 'score': 0.9997710585594177},
#  {'label': 'LABEL_2', 'score': 0.9998230338096619},
#  {'label': 'LABEL_2', 'score': 0.9991911053657532},
#  {'label': 'LABEL_2', 'score': 0.999795138835907},
#  {'label': 'LABEL_2', 'score': 0.9998687505722046},
#  {'label': 'LABEL_2', 'score': 0.9998725652694702},
#  {'label': 'LABEL_2', 'score': 0.9753604531288147},
#  {'label': 'LABEL_1', 'score': 0.9853011965751648},
#  {'label': 'LABEL_2', 'score': 0.9882119297981262},
#  {'label': 'LABEL_2', 'score': 0.9998779296875},
#  {'label': 'LABEL_2', 'score': 0.999853253364563},
#  {'label': 'LABEL_2', 'score': 0.9998658895492554},
#  {'label': 'LABEL_2', 'score': 0.9708155989646912},
#  {'label': 'LABEL_2', 'score': 0.9998739957809448},
#  {'label': 'LABEL_2', 'score': 0.9994783997535706},
#  {'label': 'LABEL_2', 'score': 0.9997296929359436},
#  {'label': 'LABEL_2', 'score': 0.9998216032981873},
#  {'label': 'LABEL_1', 'score': 0.989501416683197},
#  {'label': 'LABEL_2', 'score': 0.9996907711029053},
#  {'label': 'LABEL_1', 'score': 0.9898215532302856},
#  {'label': 'LABEL_2', 'score': 0.999783456325531},
#  {'label': 'LABEL_1', 'score': 0.9884965419769287},
#  {'label': 'LABEL_2', 'score': 0.9997815489768982},
#  {'label': 'LABEL_2', 'score': 0.9998620748519897},
#  {'label': 'LABEL_2', 'score': 0.9996007084846497},
#  {'label': 'LABEL_2', 'score': 0.9998750686645508},
#  {'label': 'LABEL_1', 'score': 0.9901325702667236},
#  {'label': 'LABEL_2', 'score': 0.9996408224105835},
#  {'label': 'LABEL_2', 'score': 0.999721109867096},
#  {'label': 'LABEL_2', 'score': 0.9981493949890137},
#  {'label': 'LABEL_1', 'score': 0.9572499394416809},
#  {'label': 'LABEL_2', 'score': 0.9996838569641113},
#  {'label': 'LABEL_2', 'score': 0.9998594522476196},
#  {'label': 'LABEL_2', 'score': 0.9997444748878479},
#  {'label': 'LABEL_2', 'score': 0.9946814179420471},
#  {'label': 'LABEL_2', 'score': 0.8916366100311279},
#  {'label': 'LABEL_2', 'score': 0.9997572302818298},
#  {'label': 'LABEL_2', 'score': 0.9998127818107605},
#  {'label': 'LABEL_2', 'score': 0.9998651742935181},
#  {'label': 'LABEL_2', 'score': 0.9995939135551453},
#  {'label': 'LABEL_1', 'score': 0.9800992608070374},
#  {'label': 'LABEL_2', 'score': 0.9998218417167664},
#  {'label': 'LABEL_1', 'score': 0.9868490695953369},
#  {'label': 'LABEL_2', 'score': 0.9998722076416016},
#  {'label': 'LABEL_2', 'score': 0.9998311996459961},
#  {'label': 'LABEL_1', 'score': 0.9906648397445679},
#  {'label': 'LABEL_2', 'score': 0.9997888207435608},
#  {'label': 'LABEL_2', 'score': 0.9992818236351013},
#  {'label': 'LABEL_2', 'score': 0.999853253364563},
#  {'label': 'LABEL_1', 'score': 0.9595879912376404},
#  {'label': 'LABEL_2', 'score': 0.9989485144615173},
#  {'label': 'LABEL_2', 'score': 0.992259681224823},
#  {'label': 'LABEL_2', 'score': 0.9998169541358948},
#  {'label': 'LABEL_2', 'score': 0.9985193610191345},
#  {'label': 'LABEL_2', 'score': 0.9997900128364563},
#  {'label': 'LABEL_2', 'score': 0.9997934699058533},
#  {'label': 'LABEL_2', 'score': 0.9998528957366943},
#  {'label': 'LABEL_1', 'score': 0.9459767937660217},
#  {'label': 'LABEL_2', 'score': 0.9983965754508972},
#  {'label': 'LABEL_2', 'score': 0.998855471611023},
#  {'label': 'LABEL_2', 'score': 0.9996966123580933},
#  {'label': 'LABEL_1', 'score': 0.9908243417739868},
#  {'label': 'LABEL_2', 'score': 0.9998106360435486},
#  {'label': 'LABEL_2', 'score': 0.9998051524162292},
#  {'label': 'LABEL_2', 'score': 0.9998346567153931},
#  {'label': 'LABEL_2', 'score': 0.9974472522735596},
#  {'label': 'LABEL_2', 'score': 0.9996422529220581},
#  {'label': 'LABEL_2', 'score': 0.9998769760131836},
#  {'label': 'LABEL_2', 'score': 0.999847412109375},
#  {'label': 'LABEL_2', 'score': 0.9998213648796082},
#  {'label': 'LABEL_2', 'score': 0.9998561143875122},
#  {'label': 'LABEL_2', 'score': 0.9998645782470703},
#  {'label': 'LABEL_2', 'score': 0.9998117089271545},
#  {'label': 'LABEL_2', 'score': 0.9998161196708679},
#  {'label': 'LABEL_2', 'score': 0.9998385906219482},
#  {'label': 'LABEL_2', 'score': 0.9998428821563721},
#  {'label': 'LABEL_2', 'score': 0.9997350573539734},
#  {'label': 'LABEL_1', 'score': 0.9692349433898926},
#  {'label': 'LABEL_2', 'score': 0.9938987493515015},
#  {'label': 'LABEL_2', 'score': 0.9784737229347229},
#  {'label': 'LABEL_2', 'score': 0.9998704195022583},
#  {'label': 'LABEL_2', 'score': 0.9998480081558228},
#  {'label': 'LABEL_2', 'score': 0.9945815205574036},
#  {'label': 'LABEL_2', 'score': 0.9998384714126587},
#  {'label': 'LABEL_2', 'score': 0.987162172794342},
#  {'label': 'LABEL_1', 'score': 0.9873355031013489},
#  {'label': 'LABEL_2', 'score': 0.9996485710144043},
#  {'label': 'LABEL_1', 'score': 0.983489990234375},
#  {'label': 'LABEL_2', 'score': 0.9814733862876892},
#  {'label': 'LABEL_2', 'score': 0.7360005974769592},
#  {'label': 'LABEL_2', 'score': 0.9998559951782227},
#  {'label': 'LABEL_2', 'score': 0.999804675579071},
#  {'label': 'LABEL_2', 'score': 0.9998619556427002},
#  {'label': 'LABEL_1', 'score': 0.985673725605011},
#  {'label': 'LABEL_2', 'score': 0.9998098015785217},
#  {'label': 'LABEL_2', 'score': 0.9436949491500854},
#  {'label': 'LABEL_2', 'score': 0.999863862991333},
#  {'label': 'LABEL_2', 'score': 0.9994490742683411},
#  {'label': 'LABEL_2', 'score': 0.9997968077659607},
#  {'label': 'LABEL_2', 'score': 0.9997109770774841},
#  {'label': 'LABEL_1', 'score': 0.9895109534263611},
#  {'label': 'LABEL_2', 'score': 0.9996405839920044},
#  {'label': 'LABEL_2', 'score': 0.994513750076294},
#  {'label': 'LABEL_2', 'score': 0.9988961219787598},
#  {'label': 'LABEL_2', 'score': 0.9998517036437988},
#  {'label': 'LABEL_2', 'score': 0.9998465776443481},
#  {'label': 'LABEL_2', 'score': 0.9979000091552734},
#  {'label': 'LABEL_2', 'score': 0.9995543360710144},
#  {'label': 'LABEL_2', 'score': 0.9998212456703186},
#  {'label': 'LABEL_2', 'score': 0.999864935874939},
#  {'label': 'LABEL_1', 'score': 0.9900145530700684},
#  {'label': 'LABEL_1', 'score': 0.5341027975082397},
#  {'label': 'LABEL_2', 'score': 0.9991167187690735},
#  {'label': 'LABEL_2', 'score': 0.9998599290847778},
#  {'label': 'LABEL_2', 'score': 0.9998216032981873},
#  {'label': 'LABEL_2', 'score': 0.9998711347579956},
#  {'label': 'LABEL_2', 'score': 0.9997455477714539},
#  {'label': 'LABEL_2', 'score': 0.9998500347137451},
#  {'label': 'LABEL_1', 'score': 0.9900690913200378},
#  {'label': 'LABEL_2', 'score': 0.9978838562965393},
#  {'label': 'LABEL_2', 'score': 0.998870313167572},
#  {'label': 'LABEL_1', 'score': 0.9908992052078247},
#  {'label': 'LABEL_2', 'score': 0.9992608428001404},
#  {'label': 'LABEL_2', 'score': 0.9998350143432617},
#  {'label': 'LABEL_2', 'score': 0.9998579025268555},
#  {'label': 'LABEL_2', 'score': 0.9998487234115601},
#  {'label': 'LABEL_1', 'score': 0.9879496097564697},
#  {'label': 'LABEL_2', 'score': 0.9998536109924316},
#  {'label': 'LABEL_2', 'score': 0.9967963099479675},
#  {'label': 'LABEL_2', 'score': 0.9984332919120789},
#  {'label': 'LABEL_2', 'score': 0.9998693466186523},
#  {'label': 'LABEL_1', 'score': 0.9892925024032593},
#  {'label': 'LABEL_1', 'score': 0.985144853591919},
#  {'label': 'LABEL_2', 'score': 0.9998537302017212},
#  {'label': 'LABEL_2', 'score': 0.9997287392616272},
#  {'label': 'LABEL_2', 'score': 0.9998575448989868},
#  {'label': 'LABEL_2', 'score': 0.999128520488739},
#  {'label': 'LABEL_1', 'score': 0.8335960507392883},
#  {'label': 'LABEL_2', 'score': 0.9997739195823669},
#  {'label': 'LABEL_2', 'score': 0.999864935874939},
#  {'label': 'LABEL_2', 'score': 0.9571248888969421},
#  {'label': 'LABEL_2', 'score': 0.9996254444122314},
#  {'label': 'LABEL_2', 'score': 0.9924455285072327},
#  {'label': 'LABEL_2', 'score': 0.9996417760848999},
#  {'label': 'LABEL_2', 'score': 0.9997958540916443},
#  {'label': 'LABEL_2', 'score': 0.9998563528060913},
#  {'label': 'LABEL_2', 'score': 0.9998621940612793},
#  {'label': 'LABEL_2', 'score': 0.999808132648468},
#  {'label': 'LABEL_2', 'score': 0.9994934797286987},
#  {'label': 'LABEL_2', 'score': 0.9995704293251038},
#  {'label': 'LABEL_2', 'score': 0.9998452663421631},
#  {'label': 'LABEL_2', 'score': 0.9998757839202881},
#  {'label': 'LABEL_1', 'score': 0.700529932975769},
#  {'label': 'LABEL_2', 'score': 0.9992411136627197},
#  {'label': 'LABEL_2', 'score': 0.9998708963394165},
#  {'label': 'LABEL_1', 'score': 0.9866529107093811},
#  {'label': 'LABEL_2', 'score': 0.9946808218955994},
#  {'label': 'LABEL_2', 'score': 0.9998262524604797},
#  {'label': 'LABEL_2', 'score': 0.9996786117553711},
#  {'label': 'LABEL_2', 'score': 0.843786895275116},
#  {'label': 'LABEL_2', 'score': 0.9998717308044434},
#  {'label': 'LABEL_1', 'score': 0.985114336013794},
#  {'label': 'LABEL_2', 'score': 0.9998646974563599},
#  {'label': 'LABEL_2', 'score': 0.9998409748077393},
#  {'label': 'LABEL_2', 'score': 0.9997488856315613},
#  {'label': 'LABEL_2', 'score': 0.9998785257339478},
#  {'label': 'LABEL_2', 'score': 0.9920579791069031},
#  {'label': 'LABEL_2', 'score': 0.9997581839561462},
#  {'label': 'LABEL_1', 'score': 0.986604630947113},
#  {'label': 'LABEL_1', 'score': 0.9871795773506165},
#  {'label': 'LABEL_2', 'score': 0.995902955532074},
#  {'label': 'LABEL_2', 'score': 0.9984241724014282},
#  {'label': 'LABEL_2', 'score': 0.9612420201301575},
#  {'label': 'LABEL_2', 'score': 0.9994891881942749},
#  {'label': 'LABEL_2', 'score': 0.9993465542793274},
#  {'label': 'LABEL_2', 'score': 0.9967396855354309},
#  {'label': 'LABEL_2', 'score': 0.995360791683197},
#  {'label': 'LABEL_2', 'score': 0.9996927976608276},
#  {'label': 'LABEL_2', 'score': 0.9998705387115479},
#  {'label': 'LABEL_2', 'score': 0.9998648166656494},
#  {'label': 'LABEL_2', 'score': 0.9998619556427002},
#  {'label': 'LABEL_2', 'score': 0.999872088432312},
#  {'label': 'LABEL_2', 'score': 0.9753574132919312},
#  {'label': 'LABEL_2', 'score': 0.9997715353965759},
#  {'label': 'LABEL_2', 'score': 0.9996591806411743},
#  {'label': 'LABEL_1', 'score': 0.9883291721343994},
#  {'label': 'LABEL_1', 'score': 0.9885376691818237},
#  {'label': 'LABEL_2', 'score': 0.9998667240142822},
#  {'label': 'LABEL_2', 'score': 0.9998632669448853},
#  {'label': 'LABEL_2', 'score': 0.9942810535430908},
#  {'label': 'LABEL_2', 'score': 0.9847093224525452},
#  {'label': 'LABEL_2', 'score': 0.9995310306549072},
#  {'label': 'LABEL_2', 'score': 0.9998645782470703},
#  {'label': 'LABEL_2', 'score': 0.9997759461402893},
#  {'label': 'LABEL_2', 'score': 0.9986220598220825},
#  {'label': 'LABEL_2', 'score': 0.9998456239700317},
#  {'label': 'LABEL_2', 'score': 0.9998555183410645},
#  {'label': 'LABEL_2', 'score': 0.9998296499252319},
#  {'label': 'LABEL_2', 'score': 0.9935576319694519},
#  {'label': 'LABEL_1', 'score': 0.9809123873710632},
#  {'label': 'LABEL_1', 'score': 0.9886987805366516},
#  {'label': 'LABEL_2', 'score': 0.9998666048049927},
#  {'label': 'LABEL_2', 'score': 0.9996812343597412},
#  {'label': 'LABEL_2', 'score': 0.9992245435714722},
#  {'label': 'LABEL_2', 'score': 0.9997842907905579},
#  {'label': 'LABEL_2', 'score': 0.9958894848823547},
#  {'label': 'LABEL_1', 'score': 0.9898006319999695},
#  {'label': 'LABEL_2', 'score': 0.9997233748435974},
#  {'label': 'LABEL_1', 'score': 0.9906818866729736},
#  {'label': 'LABEL_2', 'score': 0.999665379524231},
#  {'label': 'LABEL_2', 'score': 0.9997780919075012},
#  {'label': 'LABEL_1', 'score': 0.9230328798294067},
#  {'label': 'LABEL_2', 'score': 0.9991100430488586},
#  {'label': 'LABEL_2', 'score': 0.999776303768158},
#  {'label': 'LABEL_1', 'score': 0.9907037019729614},
#  {'label': 'LABEL_2', 'score': 0.9939028024673462},
#  {'label': 'LABEL_2', 'score': 0.999863862991333},
#  {'label': 'LABEL_2', 'score': 0.9997656941413879},
#  {'label': 'LABEL_1', 'score': 0.9885520935058594},
#  {'label': 'LABEL_2', 'score': 0.999735414981842},
#  {'label': 'LABEL_2', 'score': 0.9997897744178772},
#  {'label': 'LABEL_2', 'score': 0.9998331069946289},
#  {'label': 'LABEL_1', 'score': 0.9902313351631165},
#  {'label': 'LABEL_2', 'score': 0.9998136162757874},
#  {'label': 'LABEL_2', 'score': 0.9998401403427124},
#  {'label': 'LABEL_2', 'score': 0.999754011631012},
#  {'label': 'LABEL_2', 'score': 0.9997816681861877},
#  {'label': 'LABEL_2', 'score': 0.9998527765274048},
#  {'label': 'LABEL_2', 'score': 0.9998077750205994},
#  {'label': 'LABEL_2', 'score': 0.9972725510597229},
#  {'label': 'LABEL_2', 'score': 0.9997592568397522},
#  {'label': 'LABEL_2', 'score': 0.997553288936615},
#  {'label': 'LABEL_1', 'score': 0.9905691146850586},
#  {'label': 'LABEL_2', 'score': 0.9998546838760376},
#  {'label': 'LABEL_2', 'score': 0.9998654127120972},
#  {'label': 'LABEL_2', 'score': 0.999861478805542},
#  {'label': 'LABEL_2', 'score': 0.9998663663864136},
#  {'label': 'LABEL_2', 'score': 0.9998583793640137},
#  {'label': 'LABEL_2', 'score': 0.9997004270553589},
#  {'label': 'LABEL_2', 'score': 0.9998171925544739},
#  {'label': 'LABEL_1', 'score': 0.9781257510185242},
#  {'label': 'LABEL_2', 'score': 0.9996047616004944},
#  {'label': 'LABEL_2', 'score': 0.9983363747596741},
#  {'label': 'LABEL_2', 'score': 0.9998642206192017},
#  {'label': 'LABEL_2', 'score': 0.9915704727172852},
#  {'label': 'LABEL_1', 'score': 0.984675943851471},
#  {'label': 'LABEL_2', 'score': 0.9990593791007996},
#  {'label': 'LABEL_2', 'score': 0.9998693466186523},
#  {'label': 'LABEL_2', 'score': 0.9998674392700195},
#  {'label': 'LABEL_2', 'score': 0.9998738765716553},
#  {'label': 'LABEL_2', 'score': 0.9989620447158813},
#  {'label': 'LABEL_2', 'score': 0.9017460346221924},
#  {'label': 'LABEL_2', 'score': 0.9998481273651123},
#  {'label': 'LABEL_2', 'score': 0.9998657703399658},
#  {'label': 'LABEL_2', 'score': 0.999757707118988},
#  {'label': 'LABEL_2', 'score': 0.9975680708885193},
#  {'label': 'LABEL_2', 'score': 0.9997969269752502},
#  {'label': 'LABEL_2', 'score': 0.9976613521575928},
#  {'label': 'LABEL_2', 'score': 0.9998268485069275},
#  {'label': 'LABEL_2', 'score': 0.9924055933952332},
#  {'label': 'LABEL_2', 'score': 0.9998536109924316},
#  {'label': 'LABEL_2', 'score': 0.9998664855957031},
#  {'label': 'LABEL_2', 'score': 0.9982935786247253},
#  {'label': 'LABEL_1', 'score': 0.9902267456054688},
#  {'label': 'LABEL_2', 'score': 0.9996929168701172},
#  {'label': 'LABEL_2', 'score': 0.9997530579566956},
#  {'label': 'LABEL_1', 'score': 0.9906952381134033},
#  {'label': 'LABEL_2', 'score': 0.9995710253715515},
#  {'label': 'LABEL_2', 'score': 0.9998347759246826},
#  {'label': 'LABEL_2', 'score': 0.9998660087585449},
#  {'label': 'LABEL_2', 'score': 0.9825551509857178},
#  {'label': 'LABEL_2', 'score': 0.9996734857559204},
#  {'label': 'LABEL_2', 'score': 0.9995703101158142},
#  {'label': 'LABEL_2', 'score': 0.9995452761650085},
#  {'label': 'LABEL_2', 'score': 0.999873161315918},
#  {'label': 'LABEL_2', 'score': 0.9998596906661987},
#  {'label': 'LABEL_2', 'score': 0.9998699426651001},
#  {'label': 'LABEL_1', 'score': 0.9751048684120178},
#  {'label': 'LABEL_2', 'score': 0.9947050213813782},
#  {'label': 'LABEL_2', 'score': 0.9994152784347534},
#  {'label': 'LABEL_2', 'score': 0.9997410178184509},
#  {'label': 'LABEL_2', 'score': 0.9968030452728271},
#  {'label': 'LABEL_2', 'score': 0.9998672008514404},
#  {'label': 'LABEL_2', 'score': 0.9998683929443359},
#  {'label': 'LABEL_2', 'score': 0.9998559951782227},
#  {'label': 'LABEL_2', 'score': 0.9998329877853394},
#  {'label': 'LABEL_2', 'score': 0.9995827078819275},
#  {'label': 'LABEL_2', 'score': 0.9996080994606018},
#  {'label': 'LABEL_2', 'score': 0.9998645782470703},
#  {'label': 'LABEL_2', 'score': 0.9946106672286987},
#  {'label': 'LABEL_2', 'score': 0.9997105002403259},
#  {'label': 'LABEL_2', 'score': 0.9986905455589294},
#  {'label': 'LABEL_1', 'score': 0.9883556365966797},
#  {'label': 'LABEL_2', 'score': 0.9997772574424744},
#  {'label': 'LABEL_1', 'score': 0.9896312355995178},
#  {'label': 'LABEL_1', 'score': 0.9891676902770996},
#  {'label': 'LABEL_2', 'score': 0.6045874953269958},
#  {'label': 'LABEL_1', 'score': 0.7770986557006836},
#  {'label': 'LABEL_2', 'score': 0.9942785501480103},
#  {'label': 'LABEL_2', 'score': 0.9998294115066528},
#  {'label': 'LABEL_2', 'score': 0.9997698664665222},
#  {'label': 'LABEL_2', 'score': 0.9998735189437866},
#  {'label': 'LABEL_1', 'score': 0.9890023469924927},
#  {'label': 'LABEL_1', 'score': 0.9910275340080261},
#  {'label': 'LABEL_2', 'score': 0.9998544454574585},
#  {'label': 'LABEL_2', 'score': 0.999848484992981},
#  {'label': 'LABEL_2', 'score': 0.9998675584793091},
#  {'label': 'LABEL_2', 'score': 0.9994505047798157},
#  {'label': 'LABEL_2', 'score': 0.999477207660675},
#  {'label': 'LABEL_1', 'score': 0.9872411489486694},
#  {'label': 'LABEL_2', 'score': 0.9998501539230347},
#  {'label': 'LABEL_2', 'score': 0.9998233914375305},
#  {'label': 'LABEL_2', 'score': 0.9913288354873657},
#  {'label': 'LABEL_2', 'score': 0.9998687505722046},
#  {'label': 'LABEL_2', 'score': 0.9638987183570862},
#  {'label': 'LABEL_2', 'score': 0.9994731545448303},
#  {'label': 'LABEL_2', 'score': 0.9998061060905457},
#  {'label': 'LABEL_2', 'score': 0.9998409748077393},
#  {'label': 'LABEL_1', 'score': 0.9901642203330994},
#  {'label': 'LABEL_1', 'score': 0.9877326488494873},
#  {'label': 'LABEL_2', 'score': 0.9998272061347961},
#  {'label': 'LABEL_1', 'score': 0.9855540990829468},
#  {'label': 'LABEL_2', 'score': 0.9917751550674438},
#  {'label': 'LABEL_2', 'score': 0.999880313873291},
#  {'label': 'LABEL_2', 'score': 0.9834849238395691},
#  {'label': 'LABEL_2', 'score': 0.9998577833175659},
#  {'label': 'LABEL_2', 'score': 0.9998631477355957},
#  {'label': 'LABEL_2', 'score': 0.9996613264083862},
#  {'label': 'LABEL_2', 'score': 0.9997068047523499},
#  {'label': 'LABEL_2', 'score': 0.991401731967926},
#  {'label': 'LABEL_2', 'score': 0.999868631362915},
#  {'label': 'LABEL_2', 'score': 0.9687352776527405},
#  {'label': 'LABEL_2', 'score': 0.9994389414787292},
#  {'label': 'LABEL_2', 'score': 0.9998130202293396},
#  {'label': 'LABEL_2', 'score': 0.9972538352012634},
#  {'label': 'LABEL_1', 'score': 0.8930575251579285},
#  {'label': 'LABEL_2', 'score': 0.9995219707489014},
#  {'label': 'LABEL_2', 'score': 0.9976613521575928},
#  {'label': 'LABEL_2', 'score': 0.9997162222862244},
#  {'label': 'LABEL_2', 'score': 0.9994238615036011},
#  {'label': 'LABEL_2', 'score': 0.9992808699607849},
#  {'label': 'LABEL_2', 'score': 0.9997907280921936},
#  {'label': 'LABEL_2', 'score': 0.9997001886367798},
#  {'label': 'LABEL_2', 'score': 0.9998189806938171},
#  {'label': 'LABEL_2', 'score': 0.9997510313987732},
#  {'label': 'LABEL_2', 'score': 0.9998451471328735},
#  {'label': 'LABEL_1', 'score': 0.9908137917518616},
#  {'label': 'LABEL_2', 'score': 0.999738872051239},
#  {'label': 'LABEL_2', 'score': 0.999833345413208},
#  {'label': 'LABEL_1', 'score': 0.9865082502365112},
#  {'label': 'LABEL_2', 'score': 0.9984887838363647},
#  {'label': 'LABEL_2', 'score': 0.9992928504943848},
#  {'label': 'LABEL_2', 'score': 0.9997702240943909},
#  {'label': 'LABEL_2', 'score': 0.9998774528503418},
#  {'label': 'LABEL_2', 'score': 0.9941660165786743},
#  {'label': 'LABEL_2', 'score': 0.9998424053192139},
#  {'label': 'LABEL_2', 'score': 0.9997747540473938},
#  {'label': 'LABEL_1', 'score': 0.9905367493629456},
#  {'label': 'LABEL_2', 'score': 0.9998821020126343},
#  {'label': 'LABEL_1', 'score': 0.9757260680198669},
#  {'label': 'LABEL_2', 'score': 0.9998524188995361},
#  {'label': 'LABEL_2', 'score': 0.9998347759246826},
#  {'label': 'LABEL_2', 'score': 0.9995089769363403},
#  {'label': 'LABEL_1', 'score': 0.9903000593185425},
#  {'label': 'LABEL_2', 'score': 0.9996048808097839},
#  {'label': 'LABEL_2', 'score': 0.9986722469329834},
#  {'label': 'LABEL_2', 'score': 0.9893875122070312},
#  {'label': 'LABEL_2', 'score': 0.9957555532455444},
#  {'label': 'LABEL_1', 'score': 0.9887101054191589},
#  {'label': 'LABEL_2', 'score': 0.9998748302459717},
#  {'label': 'LABEL_2', 'score': 0.9996715784072876},
#  {'label': 'LABEL_2', 'score': 0.9980700612068176},
#  {'label': 'LABEL_2', 'score': 0.9998111128807068},
#  {'label': 'LABEL_2', 'score': 0.999824583530426},
#  {'label': 'LABEL_2', 'score': 0.9998341798782349},
#  {'label': 'LABEL_2', 'score': 0.9990907907485962},
#  {'label': 'LABEL_2', 'score': 0.9998722076416016},
#  {'label': 'LABEL_2', 'score': 0.9996559619903564},
#  {'label': 'LABEL_1', 'score': 0.9817197918891907},
#  {'label': 'LABEL_2', 'score': 0.9997759461402893},
#  {'label': 'LABEL_2', 'score': 0.9998069405555725},
#  {'label': 'LABEL_2', 'score': 0.9996911287307739},
#  {'label': 'LABEL_2', 'score': 0.9998127818107605},
#  {'label': 'LABEL_2', 'score': 0.999663233757019},
#  {'label': 'LABEL_2', 'score': 0.9997569918632507},
#  {'label': 'LABEL_2', 'score': 0.9997554421424866},
#  {'label': 'LABEL_2', 'score': 0.9998760223388672},
#  {'label': 'LABEL_2', 'score': 0.999883770942688},
#  {'label': 'LABEL_2', 'score': 0.9997690320014954},
#  {'label': 'LABEL_1', 'score': 0.9906696081161499},
#  {'label': 'LABEL_1', 'score': 0.9897381663322449},
#  {'label': 'LABEL_2', 'score': 0.9997338652610779},
#  {'label': 'LABEL_1', 'score': 0.9872134327888489},
#  {'label': 'LABEL_2', 'score': 0.999708354473114},
#  {'label': 'LABEL_2', 'score': 0.9997683167457581},
#  {'label': 'LABEL_2', 'score': 0.9998778104782104},
#  {'label': 'LABEL_2', 'score': 0.9998762607574463},
#  {'label': 'LABEL_2', 'score': 0.9828835129737854},
#  {'label': 'LABEL_1', 'score': 0.9902735352516174},
#  {'label': 'LABEL_2', 'score': 0.9998371601104736},
#  {'label': 'LABEL_2', 'score': 0.9998655319213867},
#  {'label': 'LABEL_2', 'score': 0.999854564666748},
#  {'label': 'LABEL_1', 'score': 0.989075779914856},
#  {'label': 'LABEL_2', 'score': 0.9976931214332581},
#  {'label': 'LABEL_2', 'score': 0.9998670816421509},
#  {'label': 'LABEL_2', 'score': 0.9998651742935181},
#  {'label': 'LABEL_2', 'score': 0.9998416900634766},
#  {'label': 'LABEL_2', 'score': 0.9998031258583069},
#  {'label': 'LABEL_2', 'score': 0.9998385906219482},
#  {'label': 'LABEL_2', 'score': 0.9995958209037781},
#  {'label': 'LABEL_2', 'score': 0.9998613595962524},
#  {'label': 'LABEL_1', 'score': 0.9849560856819153},
#  {'label': 'LABEL_2', 'score': 0.9998742341995239},
#  {'label': 'LABEL_2', 'score': 0.9997820258140564},
#  {'label': 'LABEL_2', 'score': 0.9994667172431946},
#  {'label': 'LABEL_2', 'score': 0.9998595714569092},
#  {'label': 'LABEL_2', 'score': 0.9995386600494385},
#  {'label': 'LABEL_2', 'score': 0.9996060729026794},
#  {'label': 'LABEL_1', 'score': 0.9875481128692627},
#  {'label': 'LABEL_2', 'score': 0.999854326248169},
#  {'label': 'LABEL_2', 'score': 0.9983459711074829},
#  {'label': 'LABEL_1', 'score': 0.9877980351448059},
#  {'label': 'LABEL_2', 'score': 0.9998456239700317},
#  {'label': 'LABEL_1', 'score': 0.9750249981880188},
#  {'label': 'LABEL_2', 'score': 0.9997603297233582},
#  {'label': 'LABEL_2', 'score': 0.9998416900634766},
#  {'label': 'LABEL_2', 'score': 0.99986732006073},
#  {'label': 'LABEL_2', 'score': 0.9997469782829285},
#  {'label': 'LABEL_2', 'score': 0.9945929646492004},
#  {'label': 'LABEL_1', 'score': 0.9906128644943237},
#  {'label': 'LABEL_2', 'score': 0.9998465776443481},
#  {'label': 'LABEL_2', 'score': 0.9997779726982117},
#  {'label': 'LABEL_2', 'score': 0.9997257590293884},
#  {'label': 'LABEL_2', 'score': 0.9998350143432617},
#  {'label': 'LABEL_2', 'score': 0.9998466968536377},
#  {'label': 'LABEL_2', 'score': 0.9997960925102234},
#  {'label': 'LABEL_2', 'score': 0.9995481371879578},
#  {'label': 'LABEL_2', 'score': 0.9998648166656494},
#  {'label': 'LABEL_2', 'score': 0.9998224377632141},
#  {'label': 'LABEL_2', 'score': 0.99985671043396},
#  {'label': 'LABEL_2', 'score': 0.9997022747993469},
#  {'label': 'LABEL_1', 'score': 0.8674584031105042},
#  {'label': 'LABEL_2', 'score': 0.9996994733810425},
#  {'label': 'LABEL_1', 'score': 0.9776361584663391},
#  {'label': 'LABEL_2', 'score': 0.9998518228530884},
#  {'label': 'LABEL_2', 'score': 0.9981991648674011},
#  {'label': 'LABEL_1', 'score': 0.9803516268730164},
#  {'label': 'LABEL_2', 'score': 0.9995287656784058},
#  {'label': 'LABEL_2', 'score': 0.9997400641441345},
#  {'label': 'LABEL_2', 'score': 0.9996931552886963},
#  {'label': 'LABEL_1', 'score': 0.9904116988182068},
#  {'label': 'LABEL_2', 'score': 0.9998660087585449},
#  {'label': 'LABEL_2', 'score': 0.9998655319213867},
#  {'label': 'LABEL_2', 'score': 0.9998823404312134},
#  {'label': 'LABEL_1', 'score': 0.9888592958450317},
#  {'label': 'LABEL_2', 'score': 0.9994657635688782},
#  {'label': 'LABEL_1', 'score': 0.9904734492301941},
#  {'label': 'LABEL_2', 'score': 0.9998401403427124},
#  {'label': 'LABEL_2', 'score': 0.9997636675834656},
#  {'label': 'LABEL_2', 'score': 0.999834418296814},
#  {'label': 'LABEL_2', 'score': 0.9993700385093689},
#  {'label': 'LABEL_2', 'score': 0.9990455508232117},
#  {'label': 'LABEL_2', 'score': 0.999842643737793},
#  {'label': 'LABEL_2', 'score': 0.9993597865104675},
#  {'label': 'LABEL_2', 'score': 0.9998631477355957},
#  {'label': 'LABEL_2', 'score': 0.9996410608291626},
#  {'label': 'LABEL_2', 'score': 0.9998032450675964},
#  {'label': 'LABEL_1', 'score': 0.9910151362419128},
#  {'label': 'LABEL_2', 'score': 0.9997499585151672},
#  {'label': 'LABEL_2', 'score': 0.9998446702957153},
#  {'label': 'LABEL_2', 'score': 0.9998682737350464},
#  {'label': 'LABEL_2', 'score': 0.9941971302032471},
#  ...]

# %%
def get_label(d):
    return int(d['label'].split('_')[1])

# %%
test_preds = [get_label(d) for d in test_preds]

# %%
print("accuracy:",accuracy_score(split['test']['label'],test_preds))
# Out:
# accuracy: 0.9335154826958105

# %%
print("f1 score:",f1_score(split['test']['label'],test_preds,average='macro'))
# Out:
# f1 score: 0.867339452957715
